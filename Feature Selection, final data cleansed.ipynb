# %%
import pandas as pd
from scipy.stats import chi2_contingency
import numpy as np

# %%
# Reading dataset
df = pd.read_csv(r'C:\Users\Yogesh Ubbu\Documents\Eshwar_Project\dataset_after_feature_engineering.csv'
                 ) 

df.head(5)
# Out:
#   Age Group    Household Composition Special Education Services  \
# 0     ADULT  COHABITATES WITH OTHERS             NOT APPLICABLE
# 1     ADULT              LIVES ALONE             NOT APPLICABLE
# 2     ADULT  COHABITATES WITH OTHERS             NOT APPLICABLE
# 3     ADULT           NOT APPLICABLE             NOT APPLICABLE
# 4     ADULT  COHABITATES WITH OTHERS             NOT APPLICABLE
#
#   Mental Illness No Chronic Med Condition Smokes Serious Mental Illness  \
# 0            YES                      YES     NO                    YES
# 1            YES                      YES     NO                    YES
# 2            YES                      YES    YES                    YES
# 3            YES                      YES    YES                    YES
# 4            YES                       NO    YES                    YES
#
#   Unknown Insurance Coverage Criminal Justice Status   Program_Category  ...  \
# 0                         NO                      NO  Regular Treatment  ...
# 1                         NO                      NO  Regular Treatment  ...
# 2                         NO                      NO  Regular Treatment  ...
# 3                         NO                      NO  Regular Treatment  ...
# 4                         NO                      NO  Regular Treatment  ...
#
#         Heartchronic_Summary       Disorder_summary  \
# 0  NO, HEART CHRONIC ILLNESS            NO DISORDER
# 1  NO, HEART CHRONIC ILLNESS            NO DISORDER
# 2  NO, HEART CHRONIC ILLNESS  ALCOHOL/DRUG DISORDER
# 3  NO, HEART CHRONIC ILLNESS  ALCOHOL/DRUG DISORDER
# 4  NO, HEART CHRONIC ILLNESS  ALCOHOL/DRUG DISORDER
#
#   Other_Chronic_Illness_Summmary       Brainchronic_Summary Insured_or_Not  \
# 0            NO, CHRONIC ILLNESS  NO, BRAIN CHRONIC ILLNESS            Yes
# 1            NO, CHRONIC ILLNESS  NO, BRAIN CHRONIC ILLNESS            Yes
# 2            NO, CHRONIC ILLNESS  NO, BRAIN CHRONIC ILLNESS            Yes
# 3            NO, CHRONIC ILLNESS  NO, BRAIN CHRONIC ILLNESS            Yes
# 4            NO, CHRONIC ILLNESS  NO, BRAIN CHRONIC ILLNESS            Yes
#
#   Has_Public_Insurance Has_Private_or_Other_Insurance  \
# 0                  Yes                             No
# 1                  Yes                             No
# 2                  Yes                             No
# 3                  Yes                             No
# 4                  Yes                             No
#
#   Confirmed_Medicaid_Managed Gender_Identity_Orientation  \
# 0                        Yes               Cisgender Man
# 1                        Yes               Cisgender Man
# 2                        Yes               Cisgender Man
# 3                         No               Cisgender Man
# 4                        Yes             Cisgender Woman
#
#   Receiving Cash Assistance
# 0                No/Unknown
# 1                No/Unknown
# 2                No/Unknown
# 3                       Yes
# 4                       Yes
#
# [5 rows x 38 columns]

# %%
# !pip install qgrid

import qgrid
qgrid_widget = qgrid.show_grid(df, show_toolbar=True)
qgrid_widget
# Out:
# Collecting qgrid
#   Downloading qgrid-1.3.1.tar.gz (889 kB)
#      ---------------------------------------- 0.0/889.2 kB ? eta -:--:--
#      ---------------------------------------- 889.2/889.2 kB 20.2 MB/s  0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: notebook>=4.0.0 in c:\users\yogesh ubbu\appdata\local\programs\python\python312\lib\site-packages (from qgrid) (7.4.5)
# Requirement already satisfied: pandas>=0.18.0 in c:\users\yogesh ubbu\appdata\local\programs\python\python312\lib\site-packages (from qgrid) (2.3.2)
# Requirement already satisfied: ipywidgets>=7.0.0 in c:\users\yogesh ubbu\appdata\local\programs\python\python312\lib\site-packages (from qgrid) (8.1.7)
# Requirement already satisfied: comm>=0.1.3 in c:\users\yogesh ubbu\appdata\local\programs\python\python312\lib\site-packages (from ipywidgets>=7.0.0->qgrid) (0.2.3)
# Requirement already satisfied: ipython>=6.1.0 in c:\users\yogesh ubbu\appdata\local\programs\python\python312\lib\site-packages (from ipywidgets>=7.0.0->qgrid) (9.4.0)
# Requirement already satisfied: traitlets>=4.3.1 in c:\users\yogesh ubbu\appdata\local\programs\python\python312\lib\site-packages (from ipywidgets>=7.0.0->qgrid) (5.14.3)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in c:\users\yogesh ubbu\appdata\local\programs\python\python312\lib\site-packages (from ipywidgets>=7.0.0->qgrid) (4.0.14)
# Requirement already satisfied: jupyterlab_widgets~=3.0.15 in c:\users\yogesh ubbu\appdata\local\programs\python\python312\lib\site-packages (from ipywidgets>=7.0.0->qgrid) (3.0.15)
# Requirement already satisfied: colorama in c:\users\yogesh ubbu\appdata\local\programs\python\python312\lib\site-packages (from ipython>=6.1.0->ipywidgets>=7.0.0->qgrid) (0.4.6)
# Requirement already satisfied: decorator in c:\users\yogesh ubbu\appdata\local\programs\python\python312\lib\site-packages (from ipython>=6.1.0->ipywidgets>=7.0.0->qgrid) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers in c:\users\yogesh ubbu\appdata\local\programs\python\python312\lib\site-packages (from ipython>=6.1.0->ipywidgets>=7.0.0->qgrid) (1.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\yogesh ubbu\appdata\local\programs\python\python312\lib\site-packages (from ipython>=6.1.0->ipywidgets>=7.0.0->qgrid) (0.19.2)
# Requirement already satisfied: matplotlib-inline in c:\users\yogesh ubbu\appdata\local\programs\python\python312\lib\site-packages (from ipython>=6.1.0->ipywidgets>=7.0.0->qgrid) (0.1.7)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in c:\users\yogesh ubbu\appdata\local\programs\python\python312\lib\site-packages (from ipython>=6.1.0->ipywidgets>=7.0.0->qgrid) (3.0.51)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\yogesh ubbu\appdata\local\programs\python\python312\lib\site-packages (from ipython>=6.1.0->ipywidgets>=7.0.0->qgrid) (2.19.2)
# Requirement already satisfied: stack_data in c:\users\yogesh ubbu\appdata\local\programs\python\python312\lib\site-packages (from ipython>=6.1.0->ipywidgets>=7.0.0->qgrid) (0.6.3)
# Requirement already satisfied: wcwidth in c:\users\yogesh ubbu\appdata\local\programs\python\python312\lib\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets>=7.0.0->qgrid) (0.2.13)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in c:\users\yogesh ubbu\appdata\local\programs\python\python312\lib\site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets>=7.0.0->qgrid) (0.8.5)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in c:\users\yogesh ubbu\appdata\local\programs\python\python312\lib\site-packages (from notebook>=4.0.0->qgrid) (2.17.0)
# Requirement already satisfied: jupyterlab-server<3,>=2.27.1 in c:\users\yogesh ubbu\appdata\local\programs\python\python312\lib\site-packages (from notebook>=4.0.0->qgrid) (2.27.3)
# Requirement already satisfied: jupyterlab<4.5,>=4.4.5 in c:\users\yogesh ubbu\appdata\local\programs\python\python312\lib\site-packages (from notebook>=4.0.0->qgrid) (4.4.6)
# Requirement already satisfied: notebook-shim<0.3,>=0.2 in c:\users\yogesh ubbu\appdata\local\programs\python\python312\lib\site-packages (from notebook>=4.0.0->qgrid) (0.2.4)
# Requirement already satisfied: tornado>=6.2.0 in c:\users\yogesh ubbu\appdata\local\programs\python\python312\lib\site-packages (from notebook>=4.0.0->qgrid) (6.5.2)
# Requirement already satisfied: anyio>=3.1.0 in c:\users\yogesh ubbu\appdata\local\programs\python\python312\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.0.0->qgrid) (4.10.0)
# Requirement already satisfied: argon2-cffi>=21.1 in c:\users\yogesh ubbu\appdata\local\programs\python\python312\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.0.0->qgrid) (25.1.0)
# Requirement already satisfied: jinja2>=3.0.3 in c:\users\yogesh ubbu\appdata\local\programs\python\python312\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.0.0->qgrid) (3.1.6)
# Requirement already satisfied: jupyter-client>=7.4.4 in c:\users\yogesh ubbu\appdata\local\programs\python\python312\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.0.0->qgrid) (8.6.3)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\users\yogesh ubbu\appdata\local\programs\python\python312\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.0.0->qgrid) (5.8.1)
# Requirement already satisfied: jupyter-events>=0.11.0 in c:\users\yogesh ubbu\appdata\local\programs\python\python312\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.0.0->qgrid) (0.12.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in c:\users\yogesh ubbu\appdata\local\programs\python\python312\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.0.0->qgrid) (0.5.3)
# Requirement already satisfied: nbconvert>=6.4.4 in c:\users\yogesh ubbu\appdata\local\programs\python\python312\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.0.0->qgrid) (7.16.6)
# Requirement already satisfied: nbformat>=5.3.0 in c:\users\yogesh ubbu\appdata\local\programs\python\python312\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.0.0->qgrid) (5.10.4)
# Requirement already satisfied: packaging>=22.0 in c:\users\yogesh ubbu\appdata\local\programs\python\python312\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.0.0->qgrid) (25.0)
# Requirement already satisfied: prometheus-client>=0.9 in c:\users\yogesh ubbu\appdata\local\programs\python\python312\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.0.0->qgrid) (0.22.1)
# Requirement already satisfied: pywinpty>=2.0.1 in c:\users\yogesh ubbu\appdata\local\programs\python\python312\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.0.0->qgrid) (3.0.0)
# Requirement already satisfied: pyzmq>=24 in c:\users\yogesh ubbu\appdata\local\programs\python\python312\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.0.0->qgrid) (27.0.2)
# Requirement already satisfied: send2trash>=1.8.2 in c:\users\yogesh ubbu\appdata\local\programs\python\python312\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.0.0->qgrid) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\yogesh ubbu\appdata\local\programs\python\python312\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.0.0->qgrid) (0.18.1)
# Requirement already satisfied: websocket-client>=1.7 in c:\users\yogesh ubbu\appdata\local\programs\python\python312\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.0.0->qgrid) (1.8.0)
# Requirement already satisfied: async-lru>=1.0.0 in c:\users\yogesh ubbu\appdata\local\programs\python\python312\lib\site-packages (from jupyterlab<4.5,>=4.4.5->notebook>=4.0.0->qgrid) (2.0.5)
# Requirement already satisfied: httpx<1,>=0.25.0 in c:\users\yogesh ubbu\appdata\local\programs\python\python312\lib\site-packages (from jupyterlab<4.5,>=4.4.5->notebook>=4.0.0->qgrid) (0.28.1)
# Requirement already satisfied: ipykernel!=6.30.0,>=6.5.0 in c:\users\yogesh ubbu\appdata\local\programs\python\python312\lib\site-packages (from jupyterlab<4.5,>=4.4.5->notebook>=4.0.0->qgrid) (6.30.1)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in c:\users\yogesh ubbu\appdata\local\programs\python\python312\lib\site-packages (from jupyterlab<4.5,>=4.4.5->notebook>=4.0.0->qgrid) (2.2.6)
# Requirement already satisfied: setuptools>=41.1.0 in c:\users\yogesh ubbu\appdata\local\programs\python\python312\lib\site-packages (from jupyterlab<4.5,>=4.4.5->notebook>=4.0.0->qgrid) (80.9.0)
# Requirement already satisfied: certifi in c:\users\yogesh ubbu\appdata\local\programs\python\python312\lib\site-packages (from httpx<1,>=0.25.0->jupyterlab<4.5,>=4.4.5->notebook>=4.0.0->qgrid) (2025.8.3)
# Requirement already satisfied: httpcore==1.* in c:\users\yogesh ubbu\appdata\local\programs\python\python312\lib\site-packages (from httpx<1,>=0.25.0->jupyterlab<4.5,>=4.4.5->notebook>=4.0.0->qgrid) (1.0.9)
# Requirement already satisfied: idna in c:\users\yogesh ubbu\appdata\local\programs\python\python312\lib\site-packages (from httpx<1,>=0.25.0->jupyterlab<4.5,>=4.4.5->notebook>=4.0.0->qgrid) (3.10)
# Requirement already satisfied: h11>=0.16 in c:\users\yogesh ubbu\appdata\local\programs\python\python312\lib\site-packages (from httpcore==1.*->httpx<1,>=0.25.0->jupyterlab<4.5,>=4.4.5->notebook>=4.0.0->qgrid) (0.16.0)
# Requirement already satisfied: babel>=2.10 in c:\users\yogesh ubbu\appdata\local\programs\python\python312\lib\site-packages (from jupyterlab-server<3,>=2.27.1->notebook>=4.0.0->qgrid) (2.17.0)
# Requirement already satisfied: json5>=0.9.0 in c:\users\yogesh ubbu\appdata\local\programs\python\python312\lib\site-packages (from jupyterlab-server<3,>=2.27.1->notebook>=4.0.0->qgrid) (0.12.1)
# Requirement already satisfied: jsonschema>=4.18.0 in c:\users\yogesh ubbu\appdata\local\programs\python\python312\lib\site-packages (from jupyterlab-server<3,>=2.27.1->notebook>=4.0.0->qgrid) (4.25.1)
# Requirement already satisfied: requests>=2.31 in c:\users\yogesh ubbu\appdata\local\programs\python\python312\lib\site-packages (from jupyterlab-server<3,>=2.27.1->notebook>=4.0.0->qgrid) (2.32.5)
# Requirement already satisfied: sniffio>=1.1 in c:\users\yogesh ubbu\appdata\local\programs\python\python312\lib\site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook>=4.0.0->qgrid) (1.3.1)
# Requirement already satisfied: typing_extensions>=4.5 in c:\users\yogesh ubbu\appdata\local\programs\python\python312\lib\site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook>=4.0.0->qgrid) (4.14.1)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\yogesh ubbu\appdata\local\programs\python\python312\lib\site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook>=4.0.0->qgrid) (25.1.0)
# Requirement already satisfied: debugpy>=1.6.5 in c:\users\yogesh ubbu\appdata\local\programs\python\python312\lib\site-packages (from ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.5,>=4.4.5->notebook>=4.0.0->qgrid) (1.8.16)
# Requirement already satisfied: nest-asyncio>=1.4 in c:\users\yogesh ubbu\appdata\local\programs\python\python312\lib\site-packages (from ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.5,>=4.4.5->notebook>=4.0.0->qgrid) (1.6.0)
# Requirement already satisfied: psutil>=5.7 in c:\users\yogesh ubbu\appdata\local\programs\python\python312\lib\site-packages (from ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.5,>=4.4.5->notebook>=4.0.0->qgrid) (7.0.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\yogesh ubbu\appdata\local\programs\python\python312\lib\site-packages (from jinja2>=3.0.3->jupyter-server<3,>=2.4.0->notebook>=4.0.0->qgrid) (3.0.2)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\yogesh ubbu\appdata\local\programs\python\python312\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook>=4.0.0->qgrid) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\yogesh ubbu\appdata\local\programs\python\python312\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook>=4.0.0->qgrid) (2025.4.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\yogesh ubbu\appdata\local\programs\python\python312\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook>=4.0.0->qgrid) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\yogesh ubbu\appdata\local\programs\python\python312\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook>=4.0.0->qgrid) (0.27.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\yogesh ubbu\appdata\local\programs\python\python312\lib\site-packages (from jupyter-client>=7.4.4->jupyter-server<3,>=2.4.0->notebook>=4.0.0->qgrid) (2.9.0.post0)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\yogesh ubbu\appdata\local\programs\python\python312\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->jupyter-server<3,>=2.4.0->notebook>=4.0.0->qgrid) (4.3.8)
# Requirement already satisfied: pywin32>=300 in c:\users\yogesh ubbu\appdata\local\programs\python\python312\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->jupyter-server<3,>=2.4.0->notebook>=4.0.0->qgrid) (311)
# Requirement already satisfied: python-json-logger>=2.0.4 in c:\users\yogesh ubbu\appdata\local\programs\python\python312\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook>=4.0.0->qgrid) (3.3.0)
# Requirement already satisfied: pyyaml>=5.3 in c:\users\yogesh ubbu\appdata\local\programs\python\python312\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook>=4.0.0->qgrid) (6.0.2)
# Requirement already satisfied: rfc3339-validator in c:\users\yogesh ubbu\appdata\local\programs\python\python312\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook>=4.0.0->qgrid) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in c:\users\yogesh ubbu\appdata\local\programs\python\python312\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook>=4.0.0->qgrid) (0.1.1)
# Requirement already satisfied: fqdn in c:\users\yogesh ubbu\appdata\local\programs\python\python312\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook>=4.0.0->qgrid) (1.5.1)
# Requirement already satisfied: isoduration in c:\users\yogesh ubbu\appdata\local\programs\python\python312\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook>=4.0.0->qgrid) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in c:\users\yogesh ubbu\appdata\local\programs\python\python312\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook>=4.0.0->qgrid) (3.0.0)
# Requirement already satisfied: rfc3987-syntax>=1.1.0 in c:\users\yogesh ubbu\appdata\local\programs\python\python312\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook>=4.0.0->qgrid) (1.1.0)
# Requirement already satisfied: uri-template in c:\users\yogesh ubbu\appdata\local\programs\python\python312\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook>=4.0.0->qgrid) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in c:\users\yogesh ubbu\appdata\local\programs\python\python312\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook>=4.0.0->qgrid) (24.11.1)
# Requirement already satisfied: beautifulsoup4 in c:\users\yogesh ubbu\appdata\local\programs\python\python312\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.0.0->qgrid) (4.13.5)
# Requirement already satisfied: bleach!=5.0.0 in c:\users\yogesh ubbu\appdata\local\programs\python\python312\lib\site-packages (from bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.0.0->qgrid) (6.2.0)
# Requirement already satisfied: defusedxml in c:\users\yogesh ubbu\appdata\local\programs\python\python312\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.0.0->qgrid) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in c:\users\yogesh ubbu\appdata\local\programs\python\python312\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.0.0->qgrid) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in c:\users\yogesh ubbu\appdata\local\programs\python\python312\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.0.0->qgrid) (3.1.3)
# Requirement already satisfied: nbclient>=0.5.0 in c:\users\yogesh ubbu\appdata\local\programs\python\python312\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.0.0->qgrid) (0.10.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\yogesh ubbu\appdata\local\programs\python\python312\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.0.0->qgrid) (1.5.1)
# Requirement already satisfied: webencodings in c:\users\yogesh ubbu\appdata\local\programs\python\python312\lib\site-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.0.0->qgrid) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in c:\users\yogesh ubbu\appdata\local\programs\python\python312\lib\site-packages (from bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.0.0->qgrid) (1.4.0)
# Requirement already satisfied: fastjsonschema>=2.15 in c:\users\yogesh ubbu\appdata\local\programs\python\python312\lib\site-packages (from nbformat>=5.3.0->jupyter-server<3,>=2.4.0->notebook>=4.0.0->qgrid) (2.21.2)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\yogesh ubbu\appdata\local\programs\python\python312\lib\site-packages (from pandas>=0.18.0->qgrid) (2.3.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\yogesh ubbu\appdata\local\programs\python\python312\lib\site-packages (from pandas>=0.18.0->qgrid) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\yogesh ubbu\appdata\local\programs\python\python312\lib\site-packages (from pandas>=0.18.0->qgrid) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\yogesh ubbu\appdata\local\programs\python\python312\lib\site-packages (from python-dateutil>=2.8.2->jupyter-client>=7.4.4->jupyter-server<3,>=2.4.0->notebook>=4.0.0->qgrid) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\yogesh ubbu\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.31->jupyterlab-server<3,>=2.27.1->notebook>=4.0.0->qgrid) (3.4.3)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\yogesh ubbu\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.31->jupyterlab-server<3,>=2.27.1->notebook>=4.0.0->qgrid) (2.5.0)
# Requirement already satisfied: lark>=1.2.2 in c:\users\yogesh ubbu\appdata\local\programs\python\python312\lib\site-packages (from rfc3987-syntax>=1.1.0->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook>=4.0.0->qgrid) (1.2.2)
# Requirement already satisfied: cffi>=1.0.1 in c:\users\yogesh ubbu\appdata\local\programs\python\python312\lib\site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook>=4.0.0->qgrid) (1.17.1)
# Requirement already satisfied: pycparser in c:\users\yogesh ubbu\appdata\local\programs\python\python312\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook>=4.0.0->qgrid) (2.22)
# Requirement already satisfied: soupsieve>1.2 in c:\users\yogesh ubbu\appdata\local\programs\python\python312\lib\site-packages (from beautifulsoup4->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.0.0->qgrid) (2.7)
# Requirement already satisfied: arrow>=0.15.0 in c:\users\yogesh ubbu\appdata\local\programs\python\python312\lib\site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook>=4.0.0->qgrid) (1.3.0)
# Requirement already satisfied: types-python-dateutil>=2.8.10 in c:\users\yogesh ubbu\appdata\local\programs\python\python312\lib\site-packages (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook>=4.0.0->qgrid) (2.9.0.20250822)
# Requirement already satisfied: executing>=1.2.0 in c:\users\yogesh ubbu\appdata\local\programs\python\python312\lib\site-packages (from stack_data->ipython>=6.1.0->ipywidgets>=7.0.0->qgrid) (2.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\yogesh ubbu\appdata\local\programs\python\python312\lib\site-packages (from stack_data->ipython>=6.1.0->ipywidgets>=7.0.0->qgrid) (3.0.0)
# Requirement already satisfied: pure-eval in c:\users\yogesh ubbu\appdata\local\programs\python\python312\lib\site-packages (from stack_data->ipython>=6.1.0->ipywidgets>=7.0.0->qgrid) (0.2.3)
# Building wheels for collected packages: qgrid
#   Building wheel for qgrid (pyproject.toml): started
#   Building wheel for qgrid (pyproject.toml): finished with status 'done'
#   Created wheel for qgrid: filename=qgrid-1.3.1-py2.py3-none-any.whl size=1761357 sha256=062a322ab0b9717b00f9d15366e3ab7cb93081b03760118b12cb30816468384a
#   Stored in directory: c:\users\yogesh ubbu\appdata\local\pip\cache\wheels\0a\83\df\0bccd6bcfb1923fcca59ca6f7b04f6b8d19300faf1a4edcc02
# Successfully built qgrid
# Installing collected packages: qgrid
# Successfully installed qgrid-1.3.1
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 3
#       1 get_ipython().system('pip install qgrid')
# ----> 3 import qgrid
#       4 qgrid_widget = qgrid.show_grid(df, show_toolbar=True)
#       5 qgrid_widget
#
# File c:\Users\Yogesh Ubbu\AppData\Local\Programs\Python\Python312\Lib\site-packages\qgrid\__init__.py:3
#       1 from ._version import version_info, __version__  # noqa F401
# ----> 3 from .grid import (
#       4     enable,
#       5     disable,
#       6     set_defaults,
#       7     on,
#       8     off,
#       9     set_grid_option,
#      10     show_grid,
#      11     QgridWidget,
#      12     QGridWidget,
#      13 )
#      16 def _jupyter_nbextension_paths():
#      17     return [
#      18         {
#      19             "section": "notebook",
#    (...)     23         }
#      24     ]
#
# File c:\Users\Yogesh Ubbu\AppData\Local\Programs\Python\Python312\Lib\site-packages\qgrid\grid.py:524
#     520     else:
#     521         return str(x)
# --> 524 @widgets.register()
#     525 class QgridWidget(widgets.DOMWidget):
#     526     """
#     527     The widget class which is instantiated by the ``show_grid`` method. This
#     528     class can be constructed directly but that's not recommended because
#    (...)    562
#     563     """
#     565     _view_name = Unicode('QgridView').tag(sync=True)
#
# TypeError: register() missing 1 required positional argument: 'widget'

# %%
from IPython.display import display
display(df)
# Out:
#        Age Group    Household Composition Special Education Services  \
# 0          ADULT  COHABITATES WITH OTHERS             NOT APPLICABLE
# 1          ADULT              LIVES ALONE             NOT APPLICABLE
# 2          ADULT  COHABITATES WITH OTHERS             NOT APPLICABLE
# 3          ADULT           NOT APPLICABLE             NOT APPLICABLE
# 4          ADULT  COHABITATES WITH OTHERS             NOT APPLICABLE
# ...          ...                      ...                        ...
# 194112     ADULT           NOT APPLICABLE             NOT APPLICABLE
# 194113     ADULT  COHABITATES WITH OTHERS             NOT APPLICABLE
# 194114     ADULT  COHABITATES WITH OTHERS             NOT APPLICABLE
# 194115     CHILD  COHABITATES WITH OTHERS                        YES
# 194116     ADULT                  UNKNOWN             NOT APPLICABLE
#
#        Mental Illness No Chronic Med Condition   Smokes  \
# 0                 YES                      YES       NO
# 1                 YES                      YES       NO
# 2                 YES                      YES      YES
# 3                 YES                      YES      YES
# 4                 YES                       NO      YES
# ...               ...                      ...      ...
# 194112            YES                       NO       NO
# 194113            YES                       NO       NO
# 194114            YES                      YES       NO
# 194115            YES                      YES       NO
# 194116            YES                      YES  UNKNOWN
#
#        Serious Mental Illness Unknown Insurance Coverage  \
# 0                         YES                         NO
# 1                         YES                         NO
# 2                         YES                         NO
# 3                         YES                         NO
# 4                         YES                         NO
# ...                       ...                        ...
# 194112                    YES                         NO
# 194113                    YES                         NO
# 194114                    YES                         NO
# 194115                    YES                         NO
# 194116                    YES                         NO
#
#        Criminal Justice Status   Program_Category  ...  \
# 0                           NO  Regular Treatment  ...
# 1                           NO  Regular Treatment  ...
# 2                           NO  Regular Treatment  ...
# 3                           NO  Regular Treatment  ...
# 4                           NO  Regular Treatment  ...
# ...                        ...                ...  ...
# 194112                      NO  Regular Treatment  ...
# 194113                      NO  Regular Treatment  ...
# 194114                      NO  Regular Treatment  ...
# 194115                      NO         Extra Help  ...
# 194116                      NO  Regular Treatment  ...
#
#               Heartchronic_Summary       Disorder_summary  \
# 0        NO, HEART CHRONIC ILLNESS            NO DISORDER
# 1        NO, HEART CHRONIC ILLNESS            NO DISORDER
# 2        NO, HEART CHRONIC ILLNESS  ALCOHOL/DRUG DISORDER
# 3        NO, HEART CHRONIC ILLNESS  ALCOHOL/DRUG DISORDER
# 4        NO, HEART CHRONIC ILLNESS  ALCOHOL/DRUG DISORDER
# ...                            ...                    ...
# 194112   NO, HEART CHRONIC ILLNESS            NO DISORDER
# 194113  YES, HEART CHRONIC ILLNESS            NO DISORDER
# 194114   NO, HEART CHRONIC ILLNESS            NO DISORDER
# 194115   NO, HEART CHRONIC ILLNESS            NO DISORDER
# 194116   NO, HEART CHRONIC ILLNESS                UNKNOWN
#
#        Other_Chronic_Illness_Summmary       Brainchronic_Summary  \
# 0                 NO, CHRONIC ILLNESS  NO, BRAIN CHRONIC ILLNESS
# 1                 NO, CHRONIC ILLNESS  NO, BRAIN CHRONIC ILLNESS
# 2                 NO, CHRONIC ILLNESS  NO, BRAIN CHRONIC ILLNESS
# 3                 NO, CHRONIC ILLNESS  NO, BRAIN CHRONIC ILLNESS
# 4                 NO, CHRONIC ILLNESS  NO, BRAIN CHRONIC ILLNESS
# ...                               ...                        ...
# 194112           YES, CHRONIC ILLNESS  NO, BRAIN CHRONIC ILLNESS
# 194113           YES, CHRONIC ILLNESS  NO, BRAIN CHRONIC ILLNESS
# 194114            NO, CHRONIC ILLNESS  NO, BRAIN CHRONIC ILLNESS
# 194115            NO, CHRONIC ILLNESS  NO, BRAIN CHRONIC ILLNESS
# 194116            NO, CHRONIC ILLNESS  NO, BRAIN CHRONIC ILLNESS
#
#        Insured_or_Not Has_Public_Insurance Has_Private_or_Other_Insurance  \
# 0                 Yes                  Yes                             No
# 1                 Yes                  Yes                             No
# 2                 Yes                  Yes                             No
# 3                 Yes                  Yes                             No
# 4                 Yes                  Yes                             No
# ...               ...                  ...                            ...
# 194112            Yes                  Yes                             No
# 194113            Yes                  Yes                             No
# 194114            Yes                  Yes                             No
# 194115            Yes                  Yes                             No
# 194116            Yes                  Yes                             No
#
#        Confirmed_Medicaid_Managed Gender_Identity_Orientation  \
# 0                             Yes               Cisgender Man
# 1                             Yes               Cisgender Man
# 2                             Yes               Cisgender Man
# 3                              No               Cisgender Man
# 4                             Yes             Cisgender Woman
# ...                           ...                         ...
# 194112                        Yes             Cisgender Woman
# 194113                         No               Cisgender Man
# 194114                         No               Cisgender Man
# 194115                        Yes             Cisgender Woman
# 194116                        Yes               Cisgender Man
#
#        Receiving Cash Assistance
# 0                     No/Unknown
# 1                     No/Unknown
# 2                     No/Unknown
# 3                            Yes
# 4                            Yes
# ...                          ...
# 194112                       Yes
# 194113                       Yes
# 194114                       Yes
# 194115                       Yes
# 194116                No/Unknown
#
# [194117 rows x 38 columns]

# %%
target_col = 'Mental Illness'
categorical_cols = [col for col in df.columns if col != target_col]

# %%
# Perfromng Chi-Square test to check the significance of categorical features with respect to the target variable.

# Purpose:
#   To check if there is a significant association between two categorical variables.
#
# How it works:
#   - Compares observed frequencies vs. expected frequencies (if variables were independent).
#   - Formula: χ² = Σ ((O - E)² / E)
#     where O = Observed frequency, E = Expected frequency.
#
# Hypotheses:
#   H₀ (Null): Variables are independent (no association).
#   H₁ (Alt): Variables are dependent (association exists).
#
# p-value interpretation:
#   - p < 0.05 → Reject H₀ → Significant association.
#   - p ≥ 0.05 → Fail to reject H₀ → No significant association.
#
#   - Use for categorical variables only.

# Cramér's V (Effect Size for Chi-Square Test)
# --------------------------------------------
# Purpose:
#   To measure the strength of association between two categorical variables.
#
# Formula:
#   V = sqrt( χ² / (n * (k - 1)) )
#     where:
#       χ² = Chi-square statistic
#       n = Total sample size
#       k = min(number of rows, number of columns)
#
# Interpretation (general guideline):
#   0.00 - 0.10 → Very weak
#   0.11 - 0.30 → Weak to moderate
#   0.31 - 0.50 → Moderate to strong
#   > 0.50 → Very strong
#
# Notes:
#   - Unlike p-value, Cramér's V shows strength, not just significance.
#   - Values range between 0 (no association) and 1 (perfect association).


# Bonferroni Correction (Multiple Comparisons Adjustment)
# -------------------------------------------------------
# Purpose:
#   To control the family-wise error rate (FWER) when performing multiple hypothesis tests.
#   Without correction, the probability of at least one false positive (Type I error) increases
#   as the number of tests grows.
#
# Formula:
#   Adjusted α (alpha) = Original α / Number of tests
#     where:
#       Original α = Significance level (commonly 0.05)
#       Number of tests = Total number of independent statistical tests performed
#
# Interpretation:
#   - Compare each test's p-value to the adjusted α instead of the original α.
#   - If p-value < adjusted α → Result remains statistically significant after correction.
#
# Example:
#   If α = 0.05 and 10 tests → Adjusted α = 0.05 / 10 = 0.005
#   A p-value must be < 0.005 to be considered significant after Bonferroni correction.
#   - Bonferroni is conservative; reduces false positives but increases false negatives.
#   - Works best when tests are independent.
#   - Alternative methods for multiple comparisons: Holm-Bonferroni, FDR (Benjamini-Hochberg).

# %% [markdown]
# # Chi-Square Test and Bonferroni Correction
#
# - **Chi-Square Test**:
#     - Used to check if there is an association between two categorical variables.
#     - Null Hypothesis (H₀): The variables are independent (no association).
#     - Alternative Hypothesis (H₁): The variables are not independent (association exists).
#     - A smaller **p-value (< 0.05)** indicates evidence to reject H₀.
#
# - **Cramér’s V**:
#     - Measures the strength of association between categorical variables.
#     - Interpretation:
#         - 0.00 – 0.10 → Very Weak
#         - 0.11 – 0.30 → Weak to Moderate
#         - 0.31 – 0.50 → Moderate to Strong
#         - > 0.50 → Very Strong
#
# - **Bonferroni Correction**:
#     - When performing multiple hypothesis tests, the chance of Type I error (false positive) increases.
#     - Bonferroni correction adjusts the significance level:
#       **Adjusted α = Original α / Number of Tests**
#     - Example: If α = 0.05 and 11 tests → Adjusted α = 0.00455
#     - Only consider p-values < adjusted α as statistically significant after correction.

# %%
# Function to compute Cramér's V
def cramers_v(confusion_matrix):
    chi2 = chi2_contingency(confusion_matrix)[0]
    n = confusion_matrix.sum().sum()
    k = min(confusion_matrix.shape)
    return np.sqrt(chi2 / (n * (k - 1)))

# Function to interpret Cramér's V
def interpret_cramers_v(v):
    if v <= 0.10:
        return "Very Weak"
    elif v <= 0.30:
        return "Weak to Moderate"
    elif v <= 0.50:
        return "Moderate to Strong"
    else:
        return "Very Strong"

# Target variable
target_var = 'Mental Illness'  # Change this to your actual target column

# Select categorical columns (excluding target)
categorical_cols = [col for col in df.columns if col != target_var and df[col].dtype == 'object']

# Number of tests for Bonferroni correction
num_tests = len(categorical_cols)
alpha = 0.05
bonferroni_alpha = alpha / num_tests

# Collect results
results = []

for col in categorical_cols:
    # Crosstab
    ctab = pd.crosstab(df[col], df[target_var])

    # Chi-square test
    chi2, p, dof, expected = chi2_contingency(ctab)

    # Bonferroni significance
    bonferroni_significant = 'Yes' if p < bonferroni_alpha else 'No'

    # Cramér's V
    v = cramers_v(ctab)
    interpretation = interpret_cramers_v(v)

    results.append({
        'Column': col,
        'Chi-Square': round(chi2, 2),
        'p-value': round(p, 4),
        'Significant (p<0.05)': 'Yes' if p < 0.05 else 'No',
        'Bonferroni Alpha': round(bonferroni_alpha, 5),
        'Significant (Bonferroni)': bonferroni_significant,
        "Cramer's V": round(v, 3),
        'Interpretation': interpretation
    })

# Convert to DataFrame
summary_results = pd.DataFrame(results)


# Display the summary table
summary_results.head(50)
# Out:
#                              Column  Chi-Square  p-value Significant (p<0.05)  \
# 0                         Age Group     2110.14   0.0000                  Yes
# 1             Household Composition      499.65   0.0000                  Yes
# 2        Special Education Services     2458.24   0.0000                  Yes
# 3          No Chronic Med Condition     1686.87   0.0000                  Yes
# 4                            Smokes      449.41   0.0000                  Yes
# 5            Serious Mental Illness    72269.39   0.0000                  Yes
# 6        Unknown Insurance Coverage       73.06   0.0000                  Yes
# 7           Criminal Justice Status       87.47   0.0000                  Yes
# 8                  Program_Category     1245.44   0.0000                  Yes
# 9                     Region_Served        1.23   0.5409                   No
# 10                Religion_Category       49.23   0.0000                  Yes
# 11                Employment_Status      232.96   0.0000                  Yes
# 12                   Hours_Category      286.55   0.0000                  Yes
# 13               Education_Category     1679.15   0.0000                  Yes
# 14                   Veteran_Status        0.07   0.7964                   No
# 15                             RACE       62.21   0.0000                  Yes
# 16               hispanic_ethnicity       69.64   0.0000                  Yes
# 17                 Living_Situation       46.81   0.0000                  Yes
# 18                   Cultural Group        2.69   0.2606                   No
# 19                Diagnosis_Summary     8426.88   0.0000                  Yes
# 20        Mental_Disability_Summary      380.23   0.0000                  Yes
# 21               Impairment_Summary      405.81   0.0000                  Yes
# 22          Chronic_disease_Summary     1682.37   0.0000                  Yes
# 23            Canabis_Usage_Summary      215.08   0.0000                  Yes
# 24        Smoking treatment_summary      455.05   0.0000                  Yes
# 25     Service_drug_alcohol_Summary      151.41   0.0000                  Yes
# 26  Other_testchronic_group_Summary     1170.28   0.0000                  Yes
# 27             Heartchronic_Summary      240.33   0.0000                  Yes
# 28                 Disorder_summary      260.10   0.0000                  Yes
# 29   Other_Chronic_Illness_Summmary     1187.20   0.0000                  Yes
# 30             Brainchronic_Summary      135.31   0.0000                  Yes
# 31                   Insured_or_Not      149.26   0.0000                  Yes
# 32             Has_Public_Insurance      577.00   0.0000                  Yes
# 33   Has_Private_or_Other_Insurance      231.06   0.0000                  Yes
# 34       Confirmed_Medicaid_Managed      234.18   0.0000                  Yes
# 35      Gender_Identity_Orientation      188.32   0.0000                  Yes
# 36        Receiving Cash Assistance     1757.45   0.0000                  Yes
#
#     Bonferroni Alpha Significant (Bonferroni)  Cramer's V    Interpretation
# 0            0.00135                      Yes       0.104  Weak to Moderate
# 1            0.00135                      Yes       0.051         Very Weak
# 2            0.00135                      Yes       0.113  Weak to Moderate
# 3            0.00135                      Yes       0.093         Very Weak
# 4            0.00135                      Yes       0.048         Very Weak
# 5            0.00135                      Yes       0.610       Very Strong
# 6            0.00135                      Yes       0.019         Very Weak
# 7            0.00135                      Yes       0.021         Very Weak
# 8            0.00135                      Yes       0.080         Very Weak
# 9            0.00135                       No       0.003         Very Weak
# 10           0.00135                      Yes       0.016         Very Weak
# 11           0.00135                      Yes       0.035         Very Weak
# 12           0.00135                      Yes       0.038         Very Weak
# 13           0.00135                      Yes       0.093         Very Weak
# 14           0.00135                       No       0.001         Very Weak
# 15           0.00135                      Yes       0.018         Very Weak
# 16           0.00135                      Yes       0.019         Very Weak
# 17           0.00135                      Yes       0.016         Very Weak
# 18           0.00135                       No       0.004         Very Weak
# 19           0.00135                      Yes       0.208  Weak to Moderate
# 20           0.00135                      Yes       0.044         Very Weak
# 21           0.00135                      Yes       0.046         Very Weak
# 22           0.00135                      Yes       0.093         Very Weak
# 23           0.00135                      Yes       0.033         Very Weak
# 24           0.00135                      Yes       0.048         Very Weak
# 25           0.00135                      Yes       0.028         Very Weak
# 26           0.00135                      Yes       0.078         Very Weak
# 27           0.00135                      Yes       0.035         Very Weak
# 28           0.00135                      Yes       0.037         Very Weak
# 29           0.00135                      Yes       0.078         Very Weak
# 30           0.00135                      Yes       0.026         Very Weak
# 31           0.00135                      Yes       0.028         Very Weak
# 32           0.00135                      Yes       0.055         Very Weak
# 33           0.00135                      Yes       0.035         Very Weak
# 34           0.00135                      Yes       0.035         Very Weak
# 35           0.00135                      Yes       0.031         Very Weak
# 36           0.00135                      Yes       0.095         Very Weak

# %%
# 'Cultural Group', 'Veteran_Status' , 'Region_Served'  are the non-significant columns, dropping them
df.drop(columns=['Cultural Group', 'Veteran_Status' , 'Region_Served'], inplace=True)

# %%
During Chi-Square feature selection, the column "Serious Mental Illness"
showed a very strong association with the target variable (Cramer's V = 0.61).
While this indicates high predictive power, it also suggests strong information leakage,
since "Serious Mental Illness" is essentially another way of stating the target outcome.
#
# Keeping this feature would artificially inflate model performance,
# because the model would learn to "cheat" by relying almost entirely on this column
# instead of discovering useful patterns from other features.
#
# To build a fair and generalizable model, we decided to DROP "Serious Mental Illness"
# from the modeling features. However, it is still reported in the EDA section
# to highlight its strong statistical significance.

df.drop(columns=['Serious Mental Illness'], inplace=True)

# %%
for i in df.columns:
   print(f"{i} -  {df[i].unique()}")
# Out:
# Age Group -  ['ADULT' 'CHILD' 'UNKNOWN']
# Household Composition -  ['COHABITATES WITH OTHERS' 'LIVES ALONE' 'NOT APPLICABLE' 'UNKNOWN']
# Special Education Services -  ['NOT APPLICABLE' 'YES' 'NO' 'UNKNOWN']
# Mental Illness -  ['YES' 'NO']
# No Chronic Med Condition -  ['YES' 'NO' 'UNKNOWN']
# Smokes -  ['NO' 'YES' 'UNKNOWN']
# Unknown Insurance Coverage -  ['NO' 'YES']
# Criminal Justice Status -  ['NO' 'YES' 'UNKNOWN']
# Program_Category -  ['Regular Treatment' 'Extra Help' 'Urgent Care']
# Religion_Category -  ['Unknown' 'Formal Religion' 'Spiritual but not Religious']
# Employment_Status -  ['Employed' 'Not in Labor Force' 'Unemployed' 'Unknown']
# Hours_Category -  ['Part-Time' 'Full-Time' 'Unknown']
# Education_Category -  ['Higher Education' 'Secondary Education' 'Unknown' 'Primary Education'
#  'No Formal Education']
# RACE -  ['WHITE' 'OTHER/MULTIRACIAL' 'BLACK' 'UNKNOWN']
# hispanic_ethnicity -  ['HISPANIC' 'NON-HISPANIC' 'UNKNOWN']
# Living_Situation -  ['PRIVATE RESIDENCE' 'OTHER' 'INSTITUTIONAL/UNKNOWN']
# Diagnosis_Summary -  ['MENTAL ILLNESS' 'NO DISORDER' 'NO ADDITIONAL DIAGNOSIS'
#  'NOT MI/DEVELOPMENT/ORGANIC/SUBSTANCEADDICTIVE/DISORDER' 'UNKNOWN']
# Mental_Disability_Summary -  ['NO DISABILITY' 'INTELECTUAL/AUTISM/DEVELOP DISABILITY' 'UNKNOWN']
# Impairment_Summary -  ['NO PHYSICAL IMPAIRMENT' 'PHYSICAL IMPAIRMENT' 'UNKNOWN']
# Chronic_disease_Summary -  ['NO CHRONICAL MEDICAL CONDITION' 'CHRONICAL MEDICAL CONDITION']
# Canabis_Usage_Summary -  ['No use cannabis' 'Use Cannabis Medical/recreational' 'UNKNOWN']
# Smoking treatment_summary -  ['No Received Smoking Medication/counseling'
#  'Received Smoking Medication/counseling' 'UNKNOWN']
# Service_drug_alcohol_Summary -  ['NO SERVICE ALCOHOL DRUG USE' 'SERVICE ALCOHOL DRUG USE' 'UNKNOWN']
# Other_testchronic_group_Summary -  ['NO, HYPERLIPIDEMIA/HIGHBLOODPRESSURE/OBESITY'
#  'YES, HYPERLIPIDEMIA/HIGHBLOODPRESSURE/OBESITY' 'UNKNOWN']
# Heartchronic_Summary -  ['NO, HEART CHRONIC ILLNESS' 'YES, HEART CHRONIC ILLNESS' 'UNKNOWN']
# Disorder_summary -  ['NO DISORDER' 'ALCOHOL/DRUG DISORDER' 'UNKNOWN']
# Other_Chronic_Illness_Summmary -  ['NO, CHRONIC ILLNESS' 'YES, CHRONIC ILLNESS']
# Brainchronic_Summary -  ['NO, BRAIN CHRONIC ILLNESS' 'YES, BRAIN CHRONIC ILLNESS' 'UNKNOWN']
# Insured_or_Not -  ['Yes' 'No']
# Has_Public_Insurance -  ['Yes' 'No']
# Has_Private_or_Other_Insurance -  ['No' 'Yes']
# Confirmed_Medicaid_Managed -  ['Yes' 'No']
# Gender_Identity_Orientation -  ['Cisgender Man' 'Cisgender Woman' 'Transgender Woman' 'Unknown'
#  'Transgender Man' 'Transgender (Unspecified)']
# Receiving Cash Assistance -  ['No/Unknown' 'Yes']

# %%
df.to_csv(r'C:\Users\Yogesh Ubbu\OneDrive\Documents\Eshwar_Project\final_data_for_model_building.csv', index=False)
